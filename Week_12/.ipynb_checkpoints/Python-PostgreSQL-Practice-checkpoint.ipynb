# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos101_db"
user = "postgres"
password = "cos101"

# Establish the connection
try:
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL SELECT query
    select_query = "SELECT  * FROM company;"

    # Execute the query
    cursor.execute(select_query)

    # Fetch all rows from the executed query
    data = cursor.fetchall()

    print("column1", " | ", "column2")
    print("------------------------")
        
    # Iterate through the rows and print them
    for row in data:
        print(f"{row[0]}       |  {row[1]}")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error connecting to PostgreSQL DB: {error}")
# Out:
# Connection to PostgreSQL DB successful
# column1  |  column2
# ------------------------
# 1       |  Chuka
# 2       |  Ethel
# 3       |  Adenike
# 4       |  Hassan
# 5       |  David
# 6       |  Chisom

# %% [markdown]
# # Create a new Database

# %%
import psycopg2
from psycopg2 import sql

# Parameters to connect to the existing PostgreSQL server
host = "localhost"
port = "5432"
dbname = "cos101_db"
user = "postgres"
password = "cos101"  # Connect to the default database

# Name of the new database to be created
new_dbname = "cos102_db"

try:
    # Connect to the PostgreSQL server
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL server successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new database
    create_db_query = sql.SQL("CREATE DATABASE {}").format(sql.Identifier(new_dbname))

    # Execute the SQL statement
    cursor.execute(create_db_query)
    print(f"Database '{new_dbname}' created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating the database: {error}")
# Out:
# Connection to PostgreSQL server successful
# Database 'cos102_db' created successfully

# %% [markdown]
# # Create a Table

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos102_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
        )
    #connection.autocommit = True  # Enable autocommit mode
    
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new table
    create_table_query = """CREATE TABLE sst_info (
        id SERIAL PRIMARY KEY,
        name     VARCHAR(50)       NOT NULL,
        age       INT              NOT NULL,
        department    VARCHAR      NOT NULL,
        password      VARCHAR      NOT NULL
    )"""

    # Execute the SQL statement
    cursor.execute(create_table_query)
    print("Table created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating table: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Error creating table: relation "sst_info" already exists

# %% [markdown]
# # INSERT into Table

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos102_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL INSERT statement
    insert_query = """
    INSERT INTO sst_info (id, name, age, department, password)
    VALUES (%s, %s, %s, %s,%s);
    """
    
    # Data to be inserted
    data_to_insert = (1, 'Jamel Ojo', 20, 'Software Engineering', 'anthelo4')

    # Execute the SQL statement
    cursor.execute(insert_query, data_to_insert)
    print("Data inserted successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error inserting data: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Data inserted successfully

# %% [markdown]
# # SELECT from Table

# %%
import psycopg2

# Define your database connection parameters
db_params = {
    'dbname': 'cos102_db',
    'user': 'postgres',
    'password': 'cos101',
    'host': 'localhost',
    'port': '5432'  # Default is '5432'
}

try:
    # Establish a connection to the database
    connection = psycopg2.connect(**db_params)

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL query
    select_query = "SELECT * FROM sst_info WHERE age < 30"
    
    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result = cursor.fetchall()
    
    # Print the results
    for row in result:
        print(row)
    
except Exception as error:
    print(f"Error while connecting to PostgreSQL: {error}")

finally:
    # Close the cursor and connection to clean up
    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
# (1, 'Jamel Ojo', 20, 'Software Engineering', 'anthelo4')

# %% [markdown]
# # Class Project I

# %% [markdown]
# Paystack is a Nigerian financial technology company that offers payment processing services to businesses. As a technology company, Paystack solves payment problems for ambitious businesses. Its mission is to help businesses in Africa become profitable, envied, and loved. They make it easy for businesses to accept secure payments from multiple local and global payment channels. They also provide tools to help you retain and acquire new customers. Currently, Paystack is restructuring the team network. It is a diverse, close-knit team on an adventure to build something enduring while learning something new, every day.

# %% [markdown]
# With your knowledge in python programming develop an application that creates the database named <b>Paystack_Team</b>. <br>The purpose of the application is to enable management to perform the following queries:
# <ul>
#     <li>Team Members in Revenue Division</li>
#     <li>Team Members in Growth and Product Division whose age is greater than 30 years but less than 35 years</li>
#     <li>Team Members in Modules 1,3 and 5</li>
#     <li>Team Members in Modules 4 and Product Division</li>
# </ul>

# %% [markdown]
# ![paystack.jpg](attachment:8cdb5248-7666-40fd-b7a3-7919507f1010.jpg)

# %%
import psycopg2
from psycopg2 import sql

# Parameters to connect to the existing PostgreSQL server
host = "localhost"
port = "5432"
dbname = "cos101_db"
user = "postgres"
password = "cos101"  # Connect to the default database

# Name of the new database to be created
new_dbname = "paystackteam_db"

try:
    # Connect to the PostgreSQL server
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL server successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new database
    create_db_query = sql.SQL("CREATE DATABASE {}").format(sql.Identifier(new_dbname))

    # Execute the SQL statement
    cursor.execute(create_db_query)
    print(f"Database '{new_dbname}' created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating the database: {error}")
# Out:
# Connection to PostgreSQL server successful
# Database 'paystackteam_db' created successfully

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "paystackteam_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
        )
    connection.autocommit = True  # Enable autocommit mode
    
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new table
    create_table_query = """CREATE TABLE paystackdetails (
        ID SERIAL PRIMARY KEY,
        NAME     VARCHAR(50)       NOT NULL,
        DIVISION   VARCHAR     NOT NULL,
        AGE      INT              NOT NULL,
        MODULE     VARCHAR      NOT NULL
    )"""

    # Execute the SQL statement
    cursor.execute(create_table_query)
    print("Table created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating table: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Table created successfully

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "paystackteam_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL INSERT statement
    insert_query = """
    INSERT INTO paystackdetails (ID, NAME, DIVISION, AGE, MODULE)
    VALUES (1, 'Oyinda Aina', 'Business', 32, 3),(2, 'Wale Eseyin', 'Engineering', 28,2),(3, 'Khadijah Abu', 'Product', 30,  5),(4, 'Onyekachi Mbaike', 'Design', 37, 4),
    (5,'Seike lbojo', 'Growth', 33, 1),(6,'Opemipo Aikomo', 'Design', 28, 3),(7, 'Ezra Olubi', 'Product', 30, 1),(8, 'Alexander Fasoro', 'Engineering', 35, 2),(9, 'Stephen Amaza', 'Growth', 40, 5),
    (10, 'Loknan Nanyak', 'Engineering', 44, 1),(11, 'Ibrahim Lawal', 'Engineering', 39, 4),(12, 'Fisayo Kolawole', 'Commercial', 27, 5),(13, 'Emmanuel Quartey', 'Growth', 31, 1),
    (14, 'Awatt Bassey', 'Growth', 32, 2),(15, 'Bolaji Akande', 'Revenue', 30, 3),(16, 'Mohini Ufeli', 'Growth', 29, 1),(17,'King Makanjuola', 'Product', 31, 4),(18, 'ljeoma Opara', 'Revenue', 26, 2),
    (19, 'Dipo Omobomi', 'Product', 32, 5),(20,'Dapo Awobokun', 'Revenue', 35, 3),(21, 'Charles Idem', 'Revenue', 38, 1),(22, 'Ayobami Alo', 'Product', 34, 4),(23,'Aminat Badara', 'Growth', 30, 2);
    """
    
    # Data to be inserted
    # data_to_insert = (1, 'Oyinda Aina', 'Business', 32, 3),(2, 'Wale Eseyin', 'Engineering', 28,2),(3, 'Khadijah Abu', 'Product', 30,  5),(4, 'Onyekachi Mbaike', 'Design', 37, 4),
    # (5,'Seike lbojo', 'Growth', 33, 1),(6,'Opemipo Aikomo', 'Design', 28, 3),(7, 'Ezra Olubi', 'Product', 30, 1),(8, 'Alexander Fasoro', 'Engineering', 35, 2),(8, 'Stephen Amaza', 'Growth', 40, 5),
    # (9, 'Loknan Nanyak', 'Engineering', 44, 1),(10, 'Ibrahim Lawal', 'Engineering', 39, 4),(11, 'Fisayo Kolawole', 'Commercial', 27, 5),(12, 'Emmanuel Quartey', 'Growth', 31, 1),
    # (13, 'Awatt Bassey', 'Growth', 32, 2),(14, 'Bolaji Akande', 'Revenue', 30, 3),(15, 'Mohini Ufeli', 'Growth', 29, 1),(16,'King Makanjuola', 'Product', 31, 4),(17, 'ljeoma Opara', 'Revenue', 26, 2),
    # (18, 'Dipo Omobomi', 'Product', 32, 5),(19,'Dapo Awobokun', 'Revenue', 35, 3),(20, 'Charles Idem', 'Revenue', 38, 1),(21, 'Ayobami Alo', 'Product', 34, 4),(22,'Aminat Badara', 'Growth', 30, 2)
                                                                                                                
    # Execute the SQL statement
    cursor.execute(insert_query)
    print("Data inserted successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error inserting data: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Data inserted successfully

# %%
import psycopg2

# Define your database connection parameters
db_params = {
    'dbname': 'paystackteam_db',
    'user': 'postgres',
    'password': 'cos101',
    'host': 'localhost',
    'port': '5432'  # Default is '5432'
}

try:
    # Establish a connection to the database
    connection = psycopg2.connect(**db_params)

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL query
    select_query = "SELECT * FROM paystackdetails WHERE DIVISION = 'Revenue'"
    
    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result = cursor.fetchall()
    
    # Print the results
    for row in result:
        print(row)
    
except Exception as error:
    print(f"Error while connecting to PostgreSQL: {error}")

finally:
    # Close the cursor and connection to clean up
    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
# (15, 'Bolaji Akande', 'Revenue', 30, '3')
# (18, 'ljeoma Opara', 'Revenue', 26, '2')
# (20, 'Dapo Awobokun', 'Revenue', 35, '3')
# (21, 'Charles Idem', 'Revenue', 38, '1')

# %%
import psycopg2

# Define your database connection parameters
db_params = {
    'dbname': 'paystackteam_db',
    'user': 'postgres',
    'password': 'cos101',
    'host': 'localhost',
    'port': '5432'  # Default is '5432'
}

try:
    # Establish a connection to the database
    connection = psycopg2.connect(**db_params)

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL query
    select_query = "SELECT * FROM paystackdetails WHERE (DIVISION = 'Growth' OR DIVISION = 'Product') AND (AGE BETWEEN 30 AND 35)"
    
    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result = cursor.fetchall()
    
    # Print the results
    for row in result:
        print(row)
    
except Exception as error:
    print(f"Error while connecting to PostgreSQL: {error}")

finally:
    # Close the cursor and connection to clean up
    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
# (3, 'Khadijah Abu', 'Product', 30, '5')
# (5, 'Seike lbojo', 'Growth', 33, '1')
# (7, 'Ezra Olubi', 'Product', 30, '1')
# (13, 'Emmanuel Quartey', 'Growth', 31, '1')
# (14, 'Awatt Bassey', 'Growth', 32, '2')
# (17, 'King Makanjuola', 'Product', 31, '4')
# (19, 'Dipo Omobomi', 'Product', 32, '5')
# (22, 'Ayobami Alo', 'Product', 34, '4')
# (23, 'Aminat Badara', 'Growth', 30, '2')

# %%
import psycopg2

# Define your database connection parameters
db_params = {
    'dbname': 'paystackteam_db',
    'user': 'postgres',
    'password': 'cos101',
    'host': 'localhost',
    'port': '5432'  # Default is '5432'
}

try:
    # Establish a connection to the database
    connection = psycopg2.connect(**db_params)

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL query
    select_query = "SELECT * FROM paystackdetails WHERE MODULE = '1' OR MODULE = '3' OR MODULE = '5' "
    
    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result = cursor.fetchall()
    
    # Print the results
    for row in result:
        print(row)
    
except Exception as error:
    print(f"Error while connecting to PostgreSQL: {error}")

finally:
    # Close the cursor and connection to clean up
    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
# (1, 'Oyinda Aina', 'Business', 32, '3')
# (3, 'Khadijah Abu', 'Product', 30, '5')
# (5, 'Seike lbojo', 'Growth', 33, '1')
# (6, 'Opemipo Aikomo', 'Design', 28, '3')
# (7, 'Ezra Olubi', 'Product', 30, '1')
# (9, 'Stephen Amaza', 'Growth', 40, '5')
# (10, 'Loknan Nanyak', 'Engineering', 44, '1')
# (12, 'Fisayo Kolawole', 'Commercial', 27, '5')
# (13, 'Emmanuel Quartey', 'Growth', 31, '1')
# (15, 'Bolaji Akande', 'Revenue', 30, '3')
# (16, 'Mohini Ufeli', 'Growth', 29, '1')
# (19, 'Dipo Omobomi', 'Product', 32, '5')
# (20, 'Dapo Awobokun', 'Revenue', 35, '3')
# (21, 'Charles Idem', 'Revenue', 38, '1')

# %%
import psycopg2

# Define your database connection parameters
db_params = {
    'dbname': 'paystackteam_db',
    'user': 'postgres',
    'password': 'cos101',
    'host': 'localhost',
    'port': '5432'  # Default is '5432'
}

try:
    # Establish a connection to the database
    connection = psycopg2.connect(**db_params)

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL query
    select_query = "SELECT * FROM paystackdetails WHERE (DIVISION = 'Product') AND (MODULE = '4')"
    
    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result = cursor.fetchall()
    
    # Print the results
    for row in result:
        print(row)
    
except Exception as error:
    print(f"Error while connecting to PostgreSQL: {error}")

finally:
    # Close the cursor and connection to clean up
    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
# (17, 'King Makanjuola', 'Product', 31, '4')
# (22, 'Ayobami Alo', 'Product', 34, '4')
